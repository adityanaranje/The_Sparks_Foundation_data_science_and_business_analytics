# %%
from IPython.display import HTML
HTML('''
<script>
code_show=false;
function code_toggle(){
    if(code_show){$('.prompt, .input, .output_stderr, .output_error').hide();}
    else{$('.input, .prompt, .output_stderr, .output_error').show();}
    code_show=!code_show;
}
function initialize(){
    document.body.style.fontFamily='Palatino';
    var output=$('.output_subarea.output_text.output_stream.output_stdout');
    $.merge(output,$('.output_subarea.output_text.output_result'));
    for(var i=0;i<output.length;i++)for(var j=0;j<output[i].children.length;j++)
        output[i].children[j].style.fontFamily='Palatino';
    code_toggle();
}
$(document).ready(initialize);
</script>
Click <a href="javascript:code_toggle()">here</a> to show/hide codes in this notebook.
''')
# Out:
# <script>
# code_show=false;
# function code_toggle(){
#     if(code_show){$('.prompt, .input, .output_stderr, .output_error').hide();}
#     else{$('.input, .prompt, .output_stderr, .output_error').show();}
#     code_show=!code_show;
# }
# function initialize(){
#     document.body.style.fontFamily='Palatino';
#     var output=$('.output_subarea.output_text.output_stream.output_stdout');
#     $.merge(output,$('.output_subarea.output_text.output_result'));
#     for(var i=0;i<output.length;i++)for(var j=0;j<output[i].children.length;j++)
#         output[i].children[j].style.fontFamily='Palatino';
#     code_toggle();
# }
# $(document).ready(initialize);
# </script>
# Click <a href="javascript:code_toggle()">here</a> to show/hide codes in this notebook.

# %% [markdown]
# # The Sparks Foundation
# ## Data Science and Business Analytics

# %% [markdown]
# ## TASK-2 Exploratory Data Analysis - Terrorism
# ### Author - Aditya Naranje

# %% [markdown]
# ## Importing all required libraries and dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action="ignore")
plt.style.use(["seaborn-bright","dark_background"])

# %%
data = pd.read_csv("globalterrorismdb_0718dist.csv", encoding='cp1252')
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
data.shape
# Out:
# (181691, 135)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
for i in data.columns:
    per = data[i].isnull().sum()
    print("Column {} has {}% data missing".format(i,round((per/len(data))*100,3)))
# Out:
# Column eventid has 0.0% data missing
# Column iyear has 0.0% data missing
# Column imonth has 0.0% data missing
# Column iday has 0.0% data missing
# Column approxdate has 94.915% data missing
# Column extended has 0.0% data missing
# Column resolution has 98.778% data missing
# Column country has 0.0% data missing
# Column country_txt has 0.0% data missing
# Column region has 0.0% data missing
# Column region_txt has 0.0% data missing
# Column provstate has 0.232% data missing
# Column city has 0.239% data missing
# Column latitude has 2.508% data missing
# Column longitude has 2.508% data missing
# Column specificity has 0.003% data missing
# Column vicinity has 0.0% data missing
# Column location has 69.456% data missing
# Column summary has 36.396% data missing
# Column crit1 has 0.0% data missing
# Column crit2 has 0.0% data missing
# Column crit3 has 0.0% data missing
# Column doubtterr has 0.001% data missing
# Column alternative has 84.033% data missing
# Column alternative_txt has 84.033% data missing
# Column multiple has 0.001% data missing
# Column success has 0.0% data missing
# Column suicide has 0.0% data missing
# Column attacktype1 has 0.0% data missing
# Column attacktype1_txt has 0.0% data missing
# Column attacktype2 has 96.525% data missing
# Column attacktype2_txt has 96.525% data missing
# Column attacktype3 has 99.764% data missing
# Column attacktype3_txt has 99.764% data missing
# Column targtype1 has 0.0% data missing
# Column targtype1_txt has 0.0% data missing
# Column targsubtype1 has 5.709% data missing
# Column targsubtype1_txt has 5.709% data missing
# Column corp1 has 23.419% data missing
# Column target1 has 0.35% data missing
# Column natlty1 has 0.858% data missing
# Column natlty1_txt has 0.858% data missing
# Column targtype2 has 93.867% data missing
# Column targtype2_txt has 93.867% data missing
# Column targsubtype2 has 94.119% data missing
# Column targsubtype2_txt has 94.119% data missing
# Column corp2 has 94.432% data missing
# Column target2 has 93.935% data missing
# Column natlty2 has 94.04% data missing
# Column natlty2_txt has 94.04% data missing
# Column targtype3 has 99.353% data missing
# Column targtype3_txt has 99.353% data missing
# Column targsubtype3 has 99.396% data missing
# Column targsubtype3_txt has 99.396% data missing
# Column corp3 has 99.435% data missing
# Column target3 has 99.353% data missing
# Column natlty3 has 99.369% data missing
# Column natlty3_txt has 99.369% data missing
# Column gname has 0.0% data missing
# Column gsubname has 96.758% data missing
# Column gname2 has 98.892% data missing
# Column gsubname2 has 99.912% data missing
# Column gname3 has 99.822% data missing
# Column gsubname3 has 99.989% data missing
# Column motive has 72.172% data missing
# Column guncertain1 has 0.209% data missing
# Column guncertain2 has 98.924% data missing
# Column guncertain3 has 99.824% data missing
# Column individual has 0.0% data missing
# Column nperps has 39.141% data missing
# Column nperpcap has 38.246% data missing
# Column claimed has 36.391% data missing
# Column claimmode has 89.497% data missing
# Column claimmode_txt has 89.497% data missing
# Column claim2 has 98.96% data missing
# Column claimmode2 has 99.661% data missing
# Column claimmode2_txt has 99.661% data missing
# Column claim3 has 99.825% data missing
# Column claimmode3 has 99.927% data missing
# Column claimmode3_txt has 99.927% data missing
# Column compclaim has 97.337% data missing
# Column weaptype1 has 0.0% data missing
# Column weaptype1_txt has 0.0% data missing
# Column weapsubtype1 has 11.43% data missing
# Column weapsubtype1_txt has 11.43% data missing
# Column weaptype2 has 92.775% data missing
# Column weaptype2_txt has 92.775% data missing
# Column weapsubtype2 has 93.647% data missing
# Column weapsubtype2_txt has 93.647% data missing
# Column weaptype3 has 98.975% data missing
# Column weaptype3_txt has 98.975% data missing
# Column weapsubtype3 has 99.068% data missing
# Column weapsubtype3_txt has 99.068% data missing
# Column weaptype4 has 99.96% data missing
# Column weaptype4_txt has 99.96% data missing
# Column weapsubtype4 has 99.961% data missing
# Column weapsubtype4_txt has 99.961% data missing
# Column weapdetail has 37.245% data missing
# Column nkill has 5.676% data missing
# Column nkillus has 35.47% data missing
# Column nkillter has 36.853% data missing
# Column nwound has 8.977% data missing
# Column nwoundus has 35.611% data missing
# Column nwoundte has 38.055% data missing
# Column property has 0.0% data missing
# Column propextent has 64.74% data missing
# Column propextent_txt has 64.74% data missing
# Column propvalue has 78.541% data missing
# Column propcomment has 68.1% data missing
# Column ishostkid has 0.098% data missing
# Column nhostkid has 92.53% data missing
# Column nhostkidus has 92.56% data missing
# Column nhours has 97.764% data missing
# Column ndays has 95.529% data missing
# Column divert has 99.822% data missing
# Column kidhijcountry has 98.181% data missing
# Column ransom has 57.411% data missing
# Column ransomamt has 99.257% data missing
# Column ransomamtus has 99.69% data missing
# Column ransompaid has 99.574% data missing
# Column ransompaidus has 99.696% data missing
# Column ransomnote has 99.717% data missing
# Column hostkidoutcome has 93.951% data missing
# Column hostkidoutcome_txt has 93.951% data missing
# Column nreleased has 94.276% data missing
# Column addnotes has 84.43% data missing
# Column scite1 has 36.431% data missing
# Column scite2 has 57.657% data missing
# Column scite3 has 76.049% data missing
# Column dbsource has 0.0% data missing
# Column INT_LOG has 0.0% data missing
# Column INT_IDEO has 0.0% data missing
# Column INT_MISC has 0.0% data missing
# Column INT_ANY has 0.0% data missing
# Column related has 86.219% data missing

# %%
for i in data.columns:
    per = data[i].isnull().sum()
    percentage = round((per/len(data))*100,3)
    if percentage>=30:
        data.drop(columns=[i],inplace=True)
        print("Column {} with {}% data missing is dropped".format(i,percentage))
# Out:
# Column approxdate with 94.915% data missing is dropped
# Column resolution with 98.778% data missing is dropped
# Column location with 69.456% data missing is dropped
# Column summary with 36.396% data missing is dropped
# Column alternative with 84.033% data missing is dropped
# Column alternative_txt with 84.033% data missing is dropped
# Column attacktype2 with 96.525% data missing is dropped
# Column attacktype2_txt with 96.525% data missing is dropped
# Column attacktype3 with 99.764% data missing is dropped
# Column attacktype3_txt with 99.764% data missing is dropped
# Column targtype2 with 93.867% data missing is dropped
# Column targtype2_txt with 93.867% data missing is dropped
# Column targsubtype2 with 94.119% data missing is dropped
# Column targsubtype2_txt with 94.119% data missing is dropped
# Column corp2 with 94.432% data missing is dropped
# Column target2 with 93.935% data missing is dropped
# Column natlty2 with 94.04% data missing is dropped
# Column natlty2_txt with 94.04% data missing is dropped
# Column targtype3 with 99.353% data missing is dropped
# Column targtype3_txt with 99.353% data missing is dropped
# Column targsubtype3 with 99.396% data missing is dropped
# Column targsubtype3_txt with 99.396% data missing is dropped
# Column corp3 with 99.435% data missing is dropped
# Column target3 with 99.353% data missing is dropped
# Column natlty3 with 99.369% data missing is dropped
# Column natlty3_txt with 99.369% data missing is dropped
# Column gsubname with 96.758% data missing is dropped
# Column gname2 with 98.892% data missing is dropped
# Column gsubname2 with 99.912% data missing is dropped
# Column gname3 with 99.822% data missing is dropped
# Column gsubname3 with 99.989% data missing is dropped
# Column motive with 72.172% data missing is dropped
# Column guncertain2 with 98.924% data missing is dropped
# Column guncertain3 with 99.824% data missing is dropped
# Column nperps with 39.141% data missing is dropped
# Column nperpcap with 38.246% data missing is dropped
# Column claimed with 36.391% data missing is dropped
# Column claimmode with 89.497% data missing is dropped
# Column claimmode_txt with 89.497% data missing is dropped
# Column claim2 with 98.96% data missing is dropped
# Column claimmode2 with 99.661% data missing is dropped
# Column claimmode2_txt with 99.661% data missing is dropped
# Column claim3 with 99.825% data missing is dropped
# Column claimmode3 with 99.927% data missing is dropped
# Column claimmode3_txt with 99.927% data missing is dropped
# Column compclaim with 97.337% data missing is dropped
# Column weaptype2 with 92.775% data missing is dropped
# Column weaptype2_txt with 92.775% data missing is dropped
# Column weapsubtype2 with 93.647% data missing is dropped
# Column weapsubtype2_txt with 93.647% data missing is dropped
# Column weaptype3 with 98.975% data missing is dropped
# Column weaptype3_txt with 98.975% data missing is dropped
# Column weapsubtype3 with 99.068% data missing is dropped
# Column weapsubtype3_txt with 99.068% data missing is dropped
# Column weaptype4 with 99.96% data missing is dropped
# Column weaptype4_txt with 99.96% data missing is dropped
# Column weapsubtype4 with 99.961% data missing is dropped
# Column weapsubtype4_txt with 99.961% data missing is dropped
# Column weapdetail with 37.245% data missing is dropped
# Column nkillus with 35.47% data missing is dropped
# Column nkillter with 36.853% data missing is dropped
# Column nwoundus with 35.611% data missing is dropped
# Column nwoundte with 38.055% data missing is dropped
# Column propextent with 64.74% data missing is dropped
# Column propextent_txt with 64.74% data missing is dropped
# Column propvalue with 78.541% data missing is dropped
# Column propcomment with 68.1% data missing is dropped
# Column nhostkid with 92.53% data missing is dropped
# Column nhostkidus with 92.56% data missing is dropped
# Column nhours with 97.764% data missing is dropped
# Column ndays with 95.529% data missing is dropped
# Column divert with 99.822% data missing is dropped
# Column kidhijcountry with 98.181% data missing is dropped
# Column ransom with 57.411% data missing is dropped
# Column ransomamt with 99.257% data missing is dropped
# Column ransomamtus with 99.69% data missing is dropped
# Column ransompaid with 99.574% data missing is dropped
# Column ransompaidus with 99.696% data missing is dropped
# Column ransomnote with 99.717% data missing is dropped
# Column hostkidoutcome with 93.951% data missing is dropped
# Column hostkidoutcome_txt with 93.951% data missing is dropped
# Column nreleased with 94.276% data missing is dropped
# Column addnotes with 84.43% data missing is dropped
# Column scite1 with 36.431% data missing is dropped
# Column scite2 with 57.657% data missing is dropped
# Column scite3 with 76.049% data missing is dropped
# Column related with 86.219% data missing is dropped

# %%
data.shape
# Out:
# (181691, 48)

# %%
data = data.dropna(axis=0,how="any")
data.shape
# Out:
# (106564, 48)

# %%
for i in data.columns:
    print("Column {} has {} unique values".format(i,data[i].nunique()))
# Out:
# Column eventid has 106564 unique values
# Column iyear has 47 unique values
# Column imonth has 12 unique values
# Column iday has 32 unique values
# Column extended has 2 unique values
# Column country has 195 unique values
# Column country_txt has 195 unique values
# Column region has 12 unique values
# Column region_txt has 12 unique values
# Column provstate has 2396 unique values
# Column city has 25350 unique values
# Column latitude has 34912 unique values
# Column longitude has 34665 unique values
# Column specificity has 4 unique values
# Column vicinity has 3 unique values
# Column crit1 has 2 unique values
# Column crit2 has 2 unique values
# Column crit3 has 2 unique values
# Column doubtterr has 3 unique values
# Column multiple has 2 unique values
# Column success has 2 unique values
# Column suicide has 2 unique values
# Column attacktype1 has 9 unique values
# Column attacktype1_txt has 9 unique values
# Column targtype1 has 21 unique values
# Column targtype1_txt has 21 unique values
# Column targsubtype1 has 112 unique values
# Column targsubtype1_txt has 112 unique values
# Column corp1 has 26364 unique values
# Column target1 has 50975 unique values
# Column natlty1 has 202 unique values
# Column natlty1_txt has 202 unique values
# Column gname has 2212 unique values
# Column guncertain1 has 2 unique values
# Column individual has 2 unique values
# Column weaptype1 has 5 unique values
# Column weaptype1_txt has 5 unique values
# Column weapsubtype1 has 30 unique values
# Column weapsubtype1_txt has 30 unique values
# Column nkill has 159 unique values
# Column nwound has 215 unique values
# Column property has 3 unique values
# Column ishostkid has 3 unique values
# Column dbsource has 24 unique values
# Column INT_LOG has 3 unique values
# Column INT_IDEO has 3 unique values
# Column INT_MISC has 2 unique values
# Column INT_ANY has 3 unique values

# %% [markdown]
# ## Number of Crimes per Year.

# %%
plt.figure(figsize=(26,6))
sns.countplot(data["iyear"])
plt.title("Comparing number of crimes per year")
plt.show()

# %% [markdown]
# ## Number of Crimes per Month.

# %%
plt.figure(figsize=(16,6))
sns.countplot(data["imonth"])
plt.title("Comparing number of crimes per month")
plt.show()

# %% [markdown]
# ## Number of Crimes per Day.

# %%
plt.figure(figsize=(26,6))
sns.countplot(data["iday"])
plt.title("Comparing number of crimes per day")
plt.show()

# %% [markdown]
# ### Pie chart for categorical data.

# %%
for i in data.columns:
    if data[i].nunique()<=10 and data[i].dtype=="object":
        data[i].value_counts().plot(kind = "pie",title=i,colors = ["purple","dodgerblue","r","darkorange","g","b","orchid","salmon","navy","silver"],
                                    autopct='%1.0f%%',figsize=(6,6))
        plt.show()

# %% [markdown]
# ### Barplot for numerical data.

# %%
x = 0
c = 1
plt.figure(figsize=(12,40))

for i in data.columns:
    if data[i].nunique()<=20 and data[i].dtype!="object":
        plt.subplot(11,2,c)
        data[i].value_counts().plot(kind = "bar",title=i,color = ["purple","dodgerblue","r","darkorange","g","b","orchid","salmon","navy","silver"])
        x = x+1
        c = c+1

# %% [markdown]
# ### Histogram for numerical data.

# %%
colours = ["purple","dodgerblue","r","darkorange","g","b","orchid","salmon","navy","silver","y","lime"]
x = 0
c = 1
plt.figure(figsize=(15,25))
for i in data.columns:
    if data[i].nunique()>20 and data[i].dtype!="object":
        plt.subplot(6,2,c)
        data[i].plot(kind = "hist",title=i,color = colours[x%12])
        x = x+1
        c = c+1

# %%
explosion = data[data["attacktype1_txt"]=="Bombing/Explosion"]
firearms = data[data["weaptype1_txt"]=="Firearms"]
hijack = data[data["attacktype1_txt"]=="Hijacking"]
kidnap = data[data["attacktype1_txt"]=="Hostage Taking (Kidnapping)"]

# %% [markdown]
# ## Crime through Bomping/Explosion in Countries.

# %%
plt.figure(figsize=(10,15))
explosion["country_txt"].value_counts().sort_values().tail(50).plot(kind = "barh",color="blue")
plt.title("Total Explosions in Countries.",fontsize=20)
plt.show()

# %% [markdown]
# ## Cirme with Firearms in Countries.

# %%
plt.figure(figsize=(10,15))
firearms["country_txt"].value_counts().sort_values().tail(50).plot(kind = "barh",color="orange")
plt.title("Total Firearms attack in Countries.",fontsize=20)
plt.show()

# %% [markdown]
# ## Total Hijacking in Countries.

# %%
plt.figure(figsize=(10,15))
hijack["country_txt"].value_counts().sort_values().tail(50).plot(kind = "barh",color="g")
plt.title("Total Hijacks in Countries.",fontsize=20)
plt.show()

# %% [markdown]
# ## Total Kidnapping in Countries.

# %%
plt.figure(figsize=(10,15))
kidnap["country_txt"].value_counts().sort_values().tail(50).plot(kind = "barh",color="silver")
plt.title("Total Kidnapps in Countries.",fontsize=20)
plt.show()

# %% [markdown]
# ## Total Crimes per Region.

# %%
plt.figure(figsize=(10,7))
data["region_txt"].value_counts().sort_values().tail(50).plot(kind = "barh",color="dodgerblue")
plt.title("Total Crimes Region.",fontsize=20)
plt.show()

# %% [markdown]
# ## Total Crimes Per Country.

# %%
plt.figure(figsize=(10,15))
data["country_txt"].value_counts().sort_values().tail(50).plot(kind = "barh",color="darkred")
plt.title("Total Crimes per Country.",fontsize=20)
plt.show()

# %%
top_countries = ["Iraq","Pakistan","Afghanistan","India","Philippines","Colombia"]

# %% [markdown]
# #### Taking insights on crime rate of top most 6 countries with most crimes.

# %%
cl = ["darkorange","b","purple","darkred","dodgerblue","y"]
x = 0
c = 1
plt.figure(figsize=(17,20))
for i in top_countries:
    country = data[data["country_txt"]==i]
    plt.subplot(3,2,c)
    country["provstate"].value_counts().sort_values().tail(20).plot(kind = "barh",color=cl[x%6])
    plt.title("Total Crimes per State In {}".format(i),fontsize=20)
    c = c+1
    x = x+1

# %% [markdown]
# #### Now Taking insights on crime rate of top most 3 states with most crimes for all above 6 states.

# %% [markdown]
# #### 1) From Iraq Bagdad, Saladin and Diyala has most of crime rate.
# #### 2) From Pakistan Balochistan, Khyber Pakhtunkhwa and Sindh has most crime rate.
# #### 3) From Afghanistan Helmand, Khandahar and Nangarhar has most crime rate.
# #### 4) Form India Jammu and Kashmir, Manipur and Chhattisgarh has most crime rate.
# #### 5) From Philippines Maguindanao, North Cotabato and Metropolitian Manila has most crime rate.
# #### 6) From Colombia Antioquia, Bogota and Norte de Santander has most crime rate.

# %%
Iraq = ["Baghdad","Saladin","Diyala"]
Pakistan = ["Balochistan","Khyber Pakhtunkhwa","Sindh"]
Afghanistan = ["Helmand","Kandahar","Nangarhar"]
India  = ["Jammu and Kashmir","Manipur","Chhattisgarh"]
Philippines = ["Maguindanao","North Cotabato","Metropolitian Manila"]
Colombia  = ["Antioquia","Bogota","Norte de Santander"]

# %% [markdown]
# ## Iraq

# %%
cl = ["dodgerblue","y","m"]
x = 0
c = 1
plt.figure(figsize=(25,6))
for i in Iraq:
    state = data[data["provstate"]==i]
    plt.subplot(1,3,c)
    state["city"].value_counts().sort_values().tail(20).plot(kind = "barh",color=cl[x%6])
    plt.title("Total Crimes per City In State {}".format(i),fontsize=20)
    c = c+1
    x = x+1

# %% [markdown]
# ## Pakistan

# %%
cl = ["r","g","c"]
x = 0
c = 1
plt.figure(figsize=(25,6))
for i in Pakistan:
    state = data[data["provstate"]==i]
    plt.subplot(1,3,c)
    state["city"].value_counts().sort_values().tail(20).plot(kind = "barh",color=cl[x%6])
    plt.title("Total Crimes per City In State {}".format(i),fontsize=20)
    c = c+1
    x = x+1

# %% [markdown]
# ## Afghannistan

# %%
cl = ["m","salmon","b"]
x = 0
c = 1
plt.figure(figsize=(25,6))
for i in Afghanistan:
    state = data[data["provstate"]==i]
    plt.subplot(1,3,c)
    state["city"].value_counts().sort_values().tail(20).plot(kind = "barh",color=cl[x%6])
    plt.title("Total Crimes per City In State {}".format(i),fontsize=20)
    c = c+1
    x = x+1

# %% [markdown]
# ## India

# %%
cl = ["darkorange","ghostwhite","g"]
x = 0
c = 1
plt.figure(figsize=(25,6))
for i in India:
    state = data[data["provstate"]==i]
    plt.subplot(1,3,c)
    state["city"].value_counts().sort_values().tail(20).plot(kind = "barh",color=cl[x%6])
    plt.title("Total Crimes per City In State {}".format(i),fontsize=20)
    c = c+1
    x = x+1

# %% [markdown]
# ## Philippines

# %%
cl = ["skyblue","r","pink"]
x = 0
c = 1
plt.figure(figsize=(25,6))
for i in Philippines:
    state = data[data["provstate"]==i]
    plt.subplot(1,3,c)
    state["city"].value_counts().sort_values().tail(20).plot(kind = "barh",color=cl[x%6])
    plt.title("Total Crimes per City In State {}".format(i),fontsize=20)
    c = c+1
    x = x+1

# %% [markdown]
# ## Colombia

# %%
cl = ["b","orchid","lime"]
x = 0
c = 1
plt.figure(figsize=(25,6))
for i in Colombia:
    state = data[data["provstate"]==i]
    plt.subplot(1,3,c)
    state["city"].value_counts().sort_values().tail(20).plot(kind = "barh",color=cl[x%6])
    plt.title("Total Crimes per City In State {}".format(i),fontsize=20)
    c = c+1
    x = x+1

# %%
HTML('''<script>initialize();</script>Click <a href="javascript:code_toggle()">here</a> to show/hide codes in this notebook.''')
# Out:
# <script>initialize();</script>Click <a href="javascript:code_toggle()">here</a> to show/hide codes in this notebook.
